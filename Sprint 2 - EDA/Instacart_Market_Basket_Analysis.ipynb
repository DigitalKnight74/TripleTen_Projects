# %% [markdown]
# <div style="border:solid blue 2px; padding: 20px">
#
# **Hello George,**
#
# Congratulations on submitting your second Python practical project! 🎉
#
# You’re making fantastic progress, and every project you complete brings you closer to mastering the skills needed to excel in data analysis. Your dedication and hard work are evident, and you should be proud of this achievement.
#
# Keep up the great momentum — let’s dive into this project together!
#
# ---
#
# You’ll find specific notes inside the project file, marked in green, yellow, or red. Below is a quick guide to what each color represents. **Note:** Please do not remove or alter my comments, as they’ll help guide future reviews and make the process smoother for both of us.
#
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer’s Comment</b>
#
# These comments highlight efficient solutions and great ideas that you can apply to future projects.
# </div>
#
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Reviewer’s Comment</b>
#
# These comments point out areas for optimization. While corrections are not mandatory, addressing them will enhance your project.
# </div>
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer’s Comment</b>
#
# These comments indicate issues that must be resolved before your project can be accepted.
# </div>
#
# ---
#
#
# **Project Review Summary**
#
# **What Went Well:**
#
# - **Data Preprocessing:** You demonstrated a strong understanding of Python by applying appropriate methods to clean and prepare the data. Excellent work!
# - **Code Quality:** Your code is both efficient and easy to read, reflecting solid technical skills and an eye for clean, maintainable code.
# - **Data Visualization:** The charts you created clearly addressed the analysis questions. They were well-formatted, insightful, and visually polished. Fantastic job!
#
#
# **Areas for Improvement:**
#
# - Please correct the way you identify the number of orders that include missing values in the `add_to_cart_order` column. Be sure to display the output of this check so the results are clear.
# - Update the chart showing the distribution of the number of orders per customer — it currently needs adjustments to accurately reflect the data.
#
# ---
#
# Feel free to add your own comments, explain the changes you’ve made, or ask questions by using the example below. Simply copy and paste the code into a Markdown cell:
#
# ```
# <div class="alert alert-info"; style="border-left: 7px solid blue">
# <b>Student’s Comment</b></div>
# ```
#
# It will appear like this:
#
# <div class="alert alert-info"; style="border-left: 7px solid blue">
# <b>Student’s Comment</b></div>
#
# ---
#
# Revisions are a natural and essential part of the learning process, so don’t be discouraged! Take your time to review the feedback and make the necessary updates. Once you’re ready, resubmit the project, and I’m confident you’ll excel on your next attempt.
#
# Remember, every challenge is an opportunity to grow. You’ve got this! 🏄
#
# </div>

# %% [markdown]
# # Instacart Market Basket Analysis

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Reviewer's comment, v. 1</b>
#
#
#
#
# A project introduction is crucial to provide context and clarity to your work. Please ensure to include this element in your future projects.
#
# For the introduction, it would be most effective to cover the following:
#
# - A brief overview of the situation or problem being addressed;
# - A clear statement of the project's objective, outlining what you aim to achieve;
# - A description of the dataset(s) you'll be using, highlighting key attributes and any relevant details;
# - A brief plan or strategy detailing how you intend to reach your goal.
#
# </div>

# %% [markdown]
# ## Importing the required libraries

# %%
# Import the libraries you'll need for this analysis
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's Comment, v. 1</b>
#
# Great work! It’s a best practice to import all necessary libraries in the first code cell, separate from loading the datasets. This way, if you need to add another library, you won’t have to reload the dataset.

# %%
# Load the datasets
# Note: These files use semicolon (;) as the separator instead of comma
orders         = pd.read_csv('/datasets/instacart_orders.csv', sep=';', header=0, )
products       = pd.read_csv('/datasets/products.csv', sep=';')
departments    = pd.read_csv('/datasets/departments.csv', sep=';')
aisles         = pd.read_csv('/datasets/aisles.csv', sep=';')
order_products = pd.read_csv('/datasets/order_products.csv', sep=';')

# %% [markdown]
# ## Analyze your data

# %% [markdown]
# In the cells below, display the datasets using `.info()` and `.head()` to gain insights into their structure and content.
#
# - `.info()`: Provides a concise summary of the dataset, including the data types, non-null counts, and memory usage.
# - `.head()`: Displays the first few rows of the dataset, offering a quick overview of the data values.

# %%
# In this cell, type "orders" below this line and execute the cell
# Gives you an overview of the DF
orders
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0        1515936   183418            11          6                 13
# 1        1690866   163593             5          5                 12
# 2        1454967    39980             4          5                 19
# 3        1768857    82516            56          0                 20
# 4        3007858   196724             2          4                 12
# ...          ...      ...           ...        ...                ...
# 478962   3210681     5617             5          1                 14
# 478963   3270802   112087             2          3                 13
# 478964    885349    82944            16          2                 11
# 478965    216274     4391             3          3                  8
# 478966   2071924     1730            18          1                 14
#
#         days_since_prior_order
# 0                         30.0
# 1                          9.0
# 2                          2.0
# 3                         10.0
# 4                         17.0
# ...                        ...
# 478962                     7.0
# 478963                     6.0
# 478964                     6.0
# 478965                     8.0
# 478966                    15.0
#
# [478967 rows x 6 columns]

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold"> <b>⚠️ Reviewer's Comment, v. 1</b>
#
# Displaying the entire contents of large dataframes can consume significant resources.
#
# A more efficient way to inspect dataframes is by using the head(), tail(), or sample() methods. The head() method will show the first five rows, tail() will display the last five rows, and sample() will return a random row. You can also specify the number of rows to display by including a different number in the parentheses.

# %%
# In this cell, type "products" below this line and execute the cell
# Gives you an overview of the DF
products
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49689       49690                      HIGH PERFORMANCE ENERGY DRINK
# 49690       49691                      ORIGINAL PANCAKE & WAFFLE MIX
# 49691       49692    ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR
# 49692       49693                             SPRING WATER BODY WASH
# 49693       49694                            BURRITO- STEAK & CHEESE
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 2            94              7
# 3            38              1
# 4             5             13
# ...         ...            ...
# 49689        64              7
# 49690       130             14
# 49691       130             14
# 49692       127             11
# 49693        38              1
#
# [49694 rows x 4 columns]

# %% [markdown]
# Repeat this process for each dataset to understand the structure, including the types of columns and rows they contain. Add additional code cells as needed for your analysis.

# %%
# In this cell, type "departments" below this line and execute the cell
# Gives you an overview of the DF
departments
# Out:
#     department_id       department
# 0               1           frozen
# 1               2            other
# 2               3           bakery
# 3               4          produce
# 4               5          alcohol
# 5               6    international
# 6               7        beverages
# 7               8             pets
# 8               9  dry goods pasta
# 9              10             bulk
# 10             11    personal care
# 11             12     meat seafood
# 12             13           pantry
# 13             14        breakfast
# 14             15     canned goods
# 15             16       dairy eggs
# 16             17        household
# 17             18           babies
# 18             19           snacks
# 19             20             deli
# 20             21          missing

# %%
# In this cell, type "aisles" below this line and execute the cell
# Gives you an overview of the DF
aisles
# Out:
#      aisle_id                       aisle
# 0           1       prepared soups salads
# 1           2           specialty cheeses
# 2           3         energy granola bars
# 3           4               instant foods
# 4           5  marinades meat preparation
# ..        ...                         ...
# 129       130    hot cereal pancake mixes
# 130       131                   dry pasta
# 131       132                      beauty
# 132       133  muscles joints pain relief
# 133       134  specialty wines champagnes
#
# [134 rows x 2 columns]

# %%
# In this cell, type "order_products" below this line and execute the cell
# Gives you an overview of the DF
order_products
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 0         2141543       11440               17.0          0
# 1          567889        1560                1.0          1
# 2         2261212       26683                1.0          1
# 3          491251        8670               35.0          1
# 4         2571142        1940                5.0          1
# ...           ...         ...                ...        ...
# 4545002    577211       15290               12.0          1
# 4545003   1219554       21914                9.0          0
# 4545004    692640       47766                4.0          1
# 4545005    319435         691                8.0          1
# 4545006   1398151       28733                9.0          0
#
# [4545007 rows x 4 columns]

# %%
# In this cell, type "orders.info() below this line and execute the cell

orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %% [markdown]
# Missing Values:
# 'order_id' = 0
# 'user_id' = 0
# 'order_number' = 0
# 'order_dow' = 0
# 'order_hour_of_day' = 0
# 'days_since_prior_order' = 28,819

# %% [markdown]
# The "Non-Null Count" column provides information about any missing values in each column of the dataset. With a total of 478,952 entries, observe any columns where the non-null count is less than this number to identify missing values.

# %%
# In this cell, run "order_products.info() below, but include the argument show_counts=True since this is a large file.
order_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  float64
#  3   reordered          int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %% [markdown]
# Repeat the use of .info() on the remaining datasets to identify missing values and understand their structure. Check the "Non-Null Count" for each dataset to spot any columns with missing values.

# %%
# In this cell, type "products.info() below this line and execute the cell
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %% [markdown]
# Missing Values:
# 'product_id' = 0
# 'product_name' = 1,258
# 'aisle_id' = 0
# 'departmnet_id' = 0

# %%
# In this cell, type "departments.info() below this line and execute the cell
departments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes

# %%
# In this cell, type "aisles.info() below this line and execute the cell
aisles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's Comment, v. 1</b>
#
# Great job! You’ve employed a comprehensive set of methods to get an initial overview of the data.
#
# Another useful method for quickly scanning a dataset is `describe()`. It provides a summary of key statistics.

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Reviewer's comment, v. 1</b>
#
#
#
#
# After you've studied the data don't forget to write a brief summary of your observations.
#
# In your observations, it is recommended to include the following:
#
# - **Column names** – Indicate if any columns require renaming.
# - **Data types** – Verify whether the current data types are optimal or need modification.
# - **Missing values** – If the non-null count is less than the total number of entries, this indicates missing values.
#
# You can easily obtain this information from the `head()` and `info()` methods on your dataset.

# %% [markdown]
# ## Find and Remove Missing Values
#
# We noticed that some columns contain missing values.
#
# Here are some useful code snippets:
#
# ```python
# # Identify missing values in each column
# print(dataset.isnull().sum())
#
# # Display rows where a specific column has missing values
# print(dataset[dataset['column_name'].isna()])
#
# # Confirm no missing values remain
# print(dataset.isnull().sum())
# ```

# %% [markdown]
# ### `products` Data Frame
#
# We will begin by addressing the missing values in the `products` data frame.

# %%
# Display rows where the product_name column has missing values
print(products[products['product_name'].isna()])
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# It seems suspicious that all rows with missing `product_name` might be associated with `aisle_id` 100 and `department_id` 21. Let’s verify this by checking if any rows with missing `product_name` have an `aisle_id` different from 100 and 21. This will help us confirm if the issue is isolated to this aisle or spread across others.

# %%
# Combine conditions to check for missing product names in aisles other than 100
print(products[
    products['product_name'].isna() & 
    (products['aisle_id']!= 100)
])
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %%
# Combine conditions to check for missing product names in departments other than 21
print(products[
    products['product_name'].isna() & 
    (products['department_id']!= 21)
])
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %% [markdown]
# To better understand the missing product_name values, let’s determine what department_id 21 and aisle_id 100 represent by referencing the departments and aisles tables.

# %%
# What is this aisle and department?
aisle_100 = aisles.loc[aisles['aisle_id'] == 100, 'aisle'].iloc[0]
department_21 = departments.loc[departments['department_id'] == 21, 'department'].iloc[0]

print(aisle_100)
print(department_21)
# Out:
# missing
# missing

# %%
# Fill missing product names with 'Unknown'
products['product_name'] = products['product_name'].fillna('Unknown')

# %% [markdown]
# <div class="alert alert-success" style="border-left: 7px solid green">
# <b>✅ Reviewer's Comment, v. 1</b>
#
# Well done! You have completed all the necessary checks and data pre-processing.
# </div>

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Reviewer's comment, v. 1</b>
#
#
#
# It's also recommended to include the intermediary conclusions after each section.

# %% [markdown]
# ### `orders` data frame
#
# Now let's fill in missing values from the `orders` table.

# %%
# Display rows where the days_since_prior_order column has missing values
print(orders[orders['days_since_prior_order'].isna()])
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 28        133707   182261             1          3                 10
# 96        787445    25685             1          6                 18
# 100       294410   111449             1          0                 19
# 103      2869915   123958             1          4                 16
# 104      2521921    42286             1          3                 18
# ...          ...      ...           ...        ...                ...
# 478895   2589657   205028             1          0                 16
# 478896   2222353   141211             1          2                 13
# 478922   2272807   204154             1          1                 15
# 478926   2499542    68810             1          4                 19
# 478945   1387033    22496             1          5                 14
#
#         days_since_prior_order
# 28                         NaN
# 96                         NaN
# 100                        NaN
# 103                        NaN
# 104                        NaN
# ...                        ...
# 478895                     NaN
# 478896                     NaN
# 478922                     NaN
# 478926                     NaN
# 478945                     NaN
#
# [28819 rows x 6 columns]

# %%
# Are there any missing values where it's not a customer's first order?
print(orders[orders['days_since_prior_order'].isna() &
            (orders['order_number'] > 1)
            ])
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# All of the missing `'days_since_prior_order'` values correspond to a customer's first ever order. This makes sense because there is no prior order! We'll leave the values as `NaN` so the column can remain numeric. Also, the `NaN` values shouldn't interfere with any calculations we might do using this column.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 1</b>
#
#
#
# Please note that you can change type of columns that contain missing values and integers / float numbers to integer / float type using special data types that support NaNs, like `'Int64'` / `'Int32'` / etc. or `'Float64'` / `'Float32'` / etc.

# %% [markdown]
# ### `order_products` data frame
#
# Now let's fill in missing values from the order_products table.

# %%
# Display rows where the add_to_cart_order column has missing values
print(order_products[order_products['add_to_cart_order'].isna()])
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 737       2449164        5068                NaN          0
# 9926      1968313       43867                NaN          0
# 14394     2926893       11688                NaN          0
# 16418     1717990        4142                NaN          0
# 30114     1959075       42828                NaN          1
# ...           ...         ...                ...        ...
# 4505662   1800005        7411                NaN          0
# 4511400   1633337         260                NaN          0
# 4517562    404157        9517                NaN          0
# 4534112   1673227       17835                NaN          0
# 4535739   1832957       17949                NaN          1
#
# [836 rows x 4 columns]

# %%
# Use .min() and .max() to find the minimum and maximum values for this column.
add_to_cart_min = order_products['add_to_cart_order'].min()
add_to_cart_max = order_products['add_to_cart_order'].max()

print(add_to_cart_min)
print(add_to_cart_max)
# Out:
# 1.0
# 64.0

# %%
# Save all order IDs with at least one missing value in 'add_to_cart_order'
missing_add_cart = order_products.loc[order_products['add_to_cart_order'].isna(), 
                                      'order_id'].tolist()

# %%
# Do all orders with missing values have more than 64 products?
# Step 1 - Find rows with missing values
missing_rows = order_products[order_products['add_to_cart_order'].isna()]

# Step 2 - Get 'order_id's with at least one missing value
orders_with_missing = missing_rows['order_id'].unique()

# Step 3 - Count total products per order for those 'order_id's
product_counts = order_products[order_products['order_id'].isin(orders_with_missing)].groupby('order_id').size()

# Step 4 - Check: do ALL these orders have more than 64 products?
all_above_64 = (product_counts > 64).all()

# Step 5 - Select ALL rows from those orders
all_items_from_orders_with_missing = order_products[order_products['order_id'].isin(orders_with_missing)]

print(f'Do all orders with missing values have > 64 products? {all_above_64}')
# Out:
# Do all orders with missing values have > 64 products? True

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid blue">
# <b>Student’s Comment</b>
#
# My step-by-step comments above should explain the changes I have made. However, the following information is contained in the following variables:
# - orders_with_missing: a set of order_ids with at least one missing value
# - product_count: total row count for each of the order_ids contained in orders_with_missing variable
# - all_above_64: gives the boolean answer to the question "Do the order_ids in 'product_count' all have > 64 items
# - all_items-from_orders_with_missing: contains the full rows from those order_ids with missing values
# </div>

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
# Please note that in **Step 1**, you're supposed to select **all items from the orders that contain at least one missing value** in the `add_to_cart_order` column — not just the rows where the value is missing. That means you should include all rows belonging to those orders, even if some of them have valid (non-missing) values.
#
# ---
#
# Also, you're not displaying the result, so it's unclear whether all the selected orders actually contain more than 64 products. Could you please print the content of the `above_64` variable so we can verify this?
#
# </div>

# %%
# Replace missing values with 999 and convert column to integer type
order_products['add_to_cart_order'] = order_products['add_to_cart_order'].fillna('999').astype('int64')

# %% [markdown]
# For some reason, any item placed in the cart 65th or later has a missing value in the `'add_to_cart_order'` column. Maybe the data type of that column in the database could only hold integer values from 1 to 64. We've decided to replace the missing values with a code value, 999, that represents an unknown placed in cart order above 64. We also converted the column to integer data type. We just need to be careful to remember this if we perform calculations using this column during our analysis.
#
# Other sensible code values we could've used are 0 or -1 because they don't show up elsewhere in the dataset and they don't have any real physical meaning for this variable.
#
# Also note that, for orders with exactly 65 items, we could replace the missing value with 65. But we're going to neglect that for now since we can't determine the 65th item for all orders with 66 items or more.

# %% [markdown]
# ## Find and Remove Duplicate Values from All the Datasets
#
# Each dataset may contain duplicate rows, which can lead to redundancy and affect the accuracy of our analysis. To handle this:
#
# 1. Use the `.duplicated()` method to identify duplicate rows. This method returns a Boolean series where `True` indicates a duplicate row.
# 2. Apply the `.drop_duplicates()` method to remove these duplicate rows, ensuring a cleaner dataset.
# 3. Optionally, you can set the `keep` parameter in `.drop_duplicates()` to specify which duplicate to retain (`'first'` or `'last'`).
#
# Here is some example code for reference:
# ```python
# # Check for duplicates
# print(dataset.duplicated().sum())  # Number of duplicate rows
#
# # View duplicate rows
# print(dataset[dataset.duplicated()]
#
# # Remove duplicates
# dataset = dataset.drop_duplicates().reset_index(drop=True)
#
# # Confirm removal
# print(dataset.duplicated().sum())  # Should return 0
# ```
#
# Repeat this process for all datasets to ensure they are free of duplicate rows.

# %% [markdown]
# ### `orders` data frame

# %%
# Find the number of duplicate rows in the orders dataframe
print(orders.duplicated().sum())
# Out:
# 15

# %%
# View the duplicate rows
print(orders[orders.duplicated()])
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
# 284038   2845099    31189            11          3                  2
# 311713   1021560    53767             3          3                  2
# 321100    408114    68324             4          3                  2
# 323900   1919531   191501            32          3                  2
# 345917   2232988    82565             1          3                  2
# 371905    391768    57671            19          3                  2
# 394347    467134    63189            21          3                  2
# 411408   1286742   183220            48          3                  2
# 415163   2282673    86751            49          3                  2
# 441599   2125197    14050            48          3                  2
#
#         days_since_prior_order
# 145574                     2.0
# 223105                    30.0
# 230807                    16.0
# 266232                     NaN
# 273805                     6.0
# 284038                     7.0
# 311713                     9.0
# 321100                    18.0
# 323900                     7.0
# 345917                     NaN
# 371905                    10.0
# 394347                     2.0
# 411408                     4.0
# 415163                     2.0
# 441599                     3.0

# %%
# Remove duplicate orders
orders = orders.drop_duplicates().reset_index(drop=True)

# %%
# Double check for duplicate rows
print(orders[orders.duplicated()])
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 1</b>
#
# Well done.

# %% [markdown]
# ### `products` data frame

# %%
# Check for fully duplicate rows
print(products[products.duplicated()])
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %%
# Check for just duplicate product IDs using subset='product_id' in duplicated()
print(products[products.duplicated(subset='product_id')])
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %% [markdown]
# Hint: To identify duplicate product names more effectively, convert the names to lowercase for consistent comparison. Use the .str.lower() method on the product_name column to standardize the text before checking for duplicates.

# %%
# Check for just duplicate product names (convert names to lowercase to compare better)
# converting to lowercase
products['product_name'] = products['product_name'].str.lower()

# Print duplicates
print(products[products.duplicated(subset='product_name')])
# Out:
#        product_id                                     product_name  aisle_id  \
# 71             72                                          unknown       100
# 109           110                                          unknown       100
# 296           297                                          unknown       100
# 416           417                                          unknown       100
# 436           437                                          unknown       100
# ...           ...                                              ...       ...
# 49689       49690                    high performance energy drink        64
# 49690       49691                    original pancake & waffle mix       130
# 49691       49692  organic instant oatmeal light maple brown sugar       130
# 49692       49693                           spring water body wash       127
# 49693       49694                          burrito- steak & cheese        38
#
#        department_id
# 71                21
# 109               21
# 296               21
# 416               21
# 436               21
# ...              ...
# 49689              7
# 49690             14
# 49691             14
# 49692             11
# 49693              1
#
# [1361 rows x 4 columns]

# %% [markdown]
# Let's see what that looks like in our dataset :

# %%
products[products['product_name'].str.lower() == 'high performance energy drink']
# Out:
#        product_id                   product_name  aisle_id  department_id
# 22540       22541  high performance energy drink        64              7
# 49689       49690  high performance energy drink        64              7

# %%
# Drop duplicate product names (case insensitive)
product_names_unique = products[~products['product_name'].str.lower().duplicated(keep='first')]

print(product_names_unique)
# Out:
#        product_id                                       product_name  \
# 0               1                         chocolate sandwich cookies
# 1               2                                   all-seasons salt
# 2               3               robust golden unsweetened oolong tea
# 3               4  smart ones classic favorites mini rigatoni wit...
# 4               5                          green chile anytime sauce
# ...           ...                                                ...
# 49683       49684          vodka- triple distilled- twist of vanilla
# 49684       49685                 en croute roast hazelnut cranberry
# 49685       49686                                   artisan baguette
# 49686       49687         smartblend healthy metabolism dry cat food
# 49687       49688                             fresh foaming cleanser
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 2            94              7
# 3            38              1
# 4             5             13
# ...         ...            ...
# 49683       124              5
# 49684        42              1
# 49685       112              3
# 49686        41              8
# 49687        73             11
#
# [48333 rows x 4 columns]

# %% [markdown]
# <div class="alert alert-warning" style="border-left: 7px solid gold">
# <b>⚠️ Reviewer's comment, v. 1</b>
#
# Please note that you're currently not dropping the duplicated rows from the `products` dataframe.
#
# ---
#
# That said, I won’t insist on this step, as the instruction seems a bit questionable — each product appears to have its own unique product ID. It might be better to first check whether any sales are associated with these product IDs before deciding to remove duplicates.
#
# </div>

# %% [markdown]
# ### `departments` data frame

# %%
# Check for duplicate entries in the departments dataframe
departments[departments.duplicated()]
# Out:
# Empty DataFrame
# Columns: [department_id, department]
# Index: []

# %% [markdown]
# ### `aisles` data frame

# %%
# Check for missing values and duplicates in the aisles dataframe
print(aisles[aisles.isnull().any(axis=1) | aisles.duplicated()])
# Out:
# Empty DataFrame
# Columns: [aisle_id, aisle]
# Index: []

# %% [markdown]
# ### `order_products` data frame

# %%
# Check for missing values and duplicate entries in the order_products dataframe
print(order_products[order_products.isnull().any(axis=1) | order_products.duplicated()])
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Reviewer's comment, v. 1</b>
#
# When checking for duplicates, it's important not to look only for fully identical rows, but also to verify the uniqueness of specific combinations that should not be repeated.
#
# In this case, for example, there should be no repetition of the combination of `order_id` and `add_to_cart_order`.
#
# To check for such duplicates, you can use one of the following:
#
# ```python
# order_products[order_products.duplicated(subset=['order_id', 'add_to_cart_order'])]
# ```
#
# or
#
# ```python
# order_products.duplicated(subset=['order_id', 'add_to_cart_order']).sum()
# ```

# %% [markdown]
# We have now successfully cleaned our data. Let's begin our exploratory data analysis.

# %% [markdown]
# # [A] Easy (must complete all to pass)

# %% [markdown]
# ### [A1] Verify that the `'order_hour_of_day'` and `'order_dow'` values in the `orders` tables are sensible (i.e. `'order_hour_of_day'` ranges from 0 to 23 and `'order_dow'` ranges from 0 to 6)
#
# To verify that the values in the `order_hour_of_day` and `order_dow` columns are sensible:
#
# 1. **Check unique values**: Use `.unique()` on each column to extract all distinct values present.
# 2. **Sort the results**: Use `sorted()` to arrange the unique values in ascending order for easier verification.
# 3. **Validate ranges**:
#    - Ensure `order_hour_of_day` values range from 0 to 23 (representing hours of the day).
#    - Ensure `order_dow` values range from 0 to 6 (representing days of the week).
#
# This process confirms that the data aligns with expected ranges and there are no out-of-bound or invalid entries.

# %%
# Extracting unique values from 'order_hour_of_day' (hod) and then Sorting in ascending order
unique_sorted_hod = sorted(orders['order_hour_of_day'].unique())

# Extracting all unique values from 'order_dow' and then Sorting in ascending order
unique_sorted_dow = sorted(orders['order_dow'].unique())

# %%
# Printing validation HOD are between 0 & 23 and DOW are between 0 & 6
print(all(0 <= x <= 23 for x in unique_sorted_hod))
print(all(0 <= x <= 6 for x in unique_sorted_dow))
# Out:
# True
# True

# %% [markdown]
# ### [A2] What time of day do people shop for groceries?
#
# To determine the time of day people shop for groceries, analyze the order_hour_of_day column in the orders dataset. Use .value_counts() to count the number of orders placed at each hour, and then sort the results by the hour for a clear chronological order.
#
# Finally, visualize the data with a bar plot to easily observe the shopping trends across different times of the day.

# %%
# Counting the Unique values for 'order_hour_of_day'
order_tod = orders.value_counts(subset='order_hour_of_day', sort=False)

# Create a Bar Plot
order_tod.plot(title='Busiest Hour of Day', x='order_hour_of_day', xlabel='Hour of Day', 
               ylabel='Number of Orders', legend=False, figsize=[5,5], kind='bar')

plt.show()

# %% [markdown]
# Most orders occur between 9:00 AM and 5:00 PM, with peaks at 10:00 AM and 3:00 PM

# %% [markdown]
# ### [A3] What day of the week do people shop for groceries?
#
# To figure out what day of the week people shop for groceries, analyze the order_dow column in the orders dataset. Use .value_counts() to count the number of orders for each day of the week, and then sort the results by the day index to maintain the correct order.
#
# Visualize the data with a bar plot to clearly observe shopping patterns across the days of the week.

# %%
# Defining day_map dictionary
day_map = {
    0: 'Sunday', 
    1: 'Monday', 
    2: 'Tuesday', 
    3: 'Wednesday', 
    4: 'Thursday', 
    5: 'Friday',
    6: 'Saturday'
}

# Creating a column with Names of Days
orders['day_name'] = orders['order_dow'].map(day_map)

# Counting Unique values, Grouping Days of Week, and Plotting
orders.groupby('day_name')['order_id'].count().plot(kind='bar', title='Busiest Days of the Week', 
                                                    xlabel='Day of the Week', ylabel='Number of Orders', 
                                                   legend=False
                                                   )

plt.show()

# %%
ordered_days = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
orders['day_name'] = pd.Categorical(orders['day_name'], categories=ordered_days, ordered=True)


# Counting Unique values, Grouping Days of Week, and Plotting
orders.groupby('day_name')['order_id'].count().plot(kind='bar', title='Busiest Days of the Week', 
                                                    xlabel='Day of the Week', ylabel='Number of Orders', 
                                                   legend=False
                                                   )

plt.show()

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid blue">
# <b>Student’s Comment</b>
#
# Thanks for pointing this out. I must have rushed through this part and didn't even notice that the days of the week were all jumbled up.
# </div>

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Reviewer's comment, v. 1</b>
#
# Great job mapping the numeric values to weekday names and creating a meaningful visualization!
#
# One small thing to improve the readability of your chart: right now the weekdays appear in alphabetical order because `groupby('day_name')` results in sorting by the string labels. To show the days in **chronological order** (Sunday to Saturday), you can convert the `day_name` column to a **categorical type** with an explicit order before plotting. Here's how you can do it:
#
# ```python
# ordered_days = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
# orders['day_name'] = pd.Categorical(orders['day_name'], categories=ordered_days, ordered=True)
# ```
#
# After this, your `groupby('day_name')` will respect the order of days when plotting.
#
# </div>

# %% [markdown]
# The data dictionary does not state which integer corresponds to which day of the week. Assuming Sunday = 0, then people place more orders at the beginning of the week (Sunday and Monday).

# %% [markdown]
# ### [A4] How long do people wait until placing another order?
#
# To understand how long people wait before placing another order, analyze the days_since_prior_order column in the orders dataset. Use .value_counts() to count how many orders were placed for each interval of days, then sort the results by the number of days for clarity.
#
# Visualize the data using a bar plot to observe patterns in ordering frequency over time.

# %%
# Counting Frequency
since_last_unique = orders.value_counts(subset='days_since_prior_order', sort=False)

# Create bar plot
since_last_unique.plot(kind='bar', title='Days Since Last Order', x='days_since_prior_order', 
                       xlabel='Number of Days', ylabel='Number of Orders', legend=False)

plt.show()

# %% [markdown]
# The 0 values probably correspond to customers who placed more than one order on the same day.
#
# The max value of 30 days and the high spike at that value is puzzling though. The spike might be explained by people who set up recurring subscriptions to automatically order once a month. But that doesn't explain why there are no values above 30 days. I would expect many customers to place orders less often than once a month. Maybe those customers were intentionally excluded from the dataset.

# %% [markdown]
# Disregarding the spike at 30 days, most people wait between 2 to 10 days in between orders. The most common wait time is 7 days. In other words, it's common for people to place weekly grocery orders. Interestingly, in the tail of the distribution we also see small spikes at 14, 21, and 28 days. These would correspond to orders every 2, 3, or 4 weeks.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 1</b>
#
# Overall – great job on this part! You’ve built excellent charts that include all the necessary elements and clearly answer the question. Well done!

# %% [markdown]
# # [B] Medium (must complete all to pass)

# %% [markdown]
# ### [B1] Is there a difference in `'order_hour_of_day'` distributions on Wednesdays and Saturdays? Plot the histograms for both days and describe the differences that you see.
#
# To determine if there’s a difference in the `order_hour_of_day` distributions on Wednesdays and Saturdays, follow these steps:
#
# 1. **Create masks** for Wednesday (`order_dow == 3`) and Saturday (`order_dow == 6`) to filter the orders data.
# 2. **Count the order hours** for each day using `.value_counts()` and sort them by hour with `.sort_index()` for clarity.
# 3. **Combine the counts** for both days into a single DataFrame using `pd.concat()`, and label the columns for easier interpretation.
#
# After preparing the data, plot histograms for both days to visually compare the distribution of order times. Look for patterns such as peaks or differences in the busiest times.

# %%
# Create Mask
wed_mask = orders['order_dow'] == 3
sat_mask = orders['order_dow'] == 6

# %%
# Count the Number of Orders per Hour per Day
wed_order_hour = orders[wed_mask]['order_hour_of_day'].value_counts().sort_index()
sat_order_hour = orders[sat_mask]['order_hour_of_day'].value_counts().sort_index()

# %%
# Create a single DF from the DFs for each day
wed_sat_combine = pd.concat([wed_order_hour, sat_order_hour], axis=1)
wed_sat_combine.columns = ['wed_number_of_orders', 'sat_number_of_orders']
wed_sat_combine.index.name = 'hour_of_day'

# %%
# Create a histogram (which requires raw data)
# Recreated raw data subsets for Wed and Sat
wed_hours = orders[wed_mask]['order_hour_of_day']
sat_hours = orders[sat_mask]['order_hour_of_day']

# Plot histogram
plt.figure(figsize=(12,6))
plt.hist([wed_hours, sat_hours], bins=range(25), label=['Wednesday', 'Saturday'],edgecolor='black')

plt.xlabel('Hour of Day')
plt.ylabel('Number of Orders')
plt.title('Orders per Hour\n Wednesday vs Saturday')
plt.xticks(range(24))
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()

# %% [markdown]
# There's a small dip from 11h to 13h on Wednesdays. This dip is absent on Saturdays. Maybe this dip can be attributed to people who don't use Instacart because they have lunch somewhere between 11h and 13h.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 1</b>
#
# Excellent visualisation!

# %% [markdown]
# ### [B2] What's the distribution for the number of orders per customer?
#
# To explore the distribution of the number of orders per customer:
#
# 1. **Group the data** by `user_id` to calculate the total number of orders for each customer. Use `.groupby('user_id')` and count the `order_id` for each group.
# 2. **Sort the results** using `.sort_values()` for better readability.
# 3. **Visualize the distribution** using a histogram to observe how many orders most customers typically place.
#
# Adjust the number of bins in the histogram to refine the visualization and better capture the pattern.

# %%
# Grouping and Sorting 'user_id' data
# Splitting and Apply aggregation to Data
user_id_grp = orders.groupby('user_id').count().reset_index()

# %%
# Create a histogram
plt.figure(figsize=(12,6))
plt.hist(user_id_grp['order_id'], bins=10, edgecolor='black')
plt.xlabel('Number of Orders')
plt.ylabel('Number of Customers')
plt.title('Distribution of Number of Orders per Customer')

plt.show()

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid blue">
# <b>Student’s Comment</b>
#
# I used .reset_index() for the user_id_grp variable. I then plotted the histogram by just the 'order_id' colunmn to get the final distribution of the Number of Orders per Customer.
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 2</b>
#
# ✔️ The chart looks good now and shows the distribution - we can see that most of the customers placed below 10 orders, and the majority - even below 5 orders.
#
#
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
# The result of your grouping operation is causing the chart to appear incorrectly — please take a look at the output below to see why.
#
# To fix this, you should either:
# - Group and count a **single** column, like this:
#
#   ```python
#   user_id_grp = orders.groupby('user_id')['order_id'].count()
#   ```
#
# **OR**
#
# - Keep your current grouping, apply `.reset_index()`, and then plot **only one column** from the resulting DataFrame:
#   ```python
#   user_id_grp = orders.groupby('user_id').count().reset_index()
#   plt.hist(user_id_grp['order_id'], bins=10, edgecolor='black')
#   ```
#
# This will ensure that your chart reflects the actual distribution of orders per user correctly.
# </div>
#
# Let me know if you want to include a quick reminder on what the histogram is meant to show.

# %%
#Added by reviewer 
#user_id_grp
# Out:
#         user_id  order_id  order_number  order_dow  order_hour_of_day  \
# 0             2         2             2          2                  2
# 1             4         2             2          2                  2
# 2             5         1             1          1                  1
# 3             6         2             2          2                  2
# 4             7         2             2          2                  2
# ...         ...       ...           ...        ...                ...
# 157432   206203         1             1          1                  1
# 157433   206206         7             7          7                  7
# 157434   206207         5             5          5                  5
# 157435   206208         9             9          9                  9
# 157436   206209         2             2          2                  2
#
#         days_since_prior_order  day_name
# 0                            1         2
# 1                            2         2
# 2                            1         1
# 3                            1         2
# 4                            2         2
# ...                        ...       ...
# 157432                       1         1
# 157433                       7         7
# 157434                       5         5
# 157435                       9         9
# 157436                       2         2
#
# [157437 rows x 7 columns]

# %% [markdown]
# Most customers in the dataset have placed between 1 and 10 orders, with number of orders per customer sharply decreasing after just 1 order.

# %% [markdown]
# ### [B3] What are the top 20 popular products (display their id and name)?
#
# To identify the top 20 most popular products:
#
# 1. **Merge the datasets**: Combine `order_products` and `products` on `product_id` to access both the product IDs and names in a single DataFrame.
# 2. **Group the data**: Group by both `product_id` and `product_name` to aggregate the order counts for each product using `.size()`.
# 3. **Sort the results**: Use `.sort_values(ascending=False)` to rank products by their popularity.
# 4. **Display the top 20**: Use `.head(20)` to focus on the most frequently ordered products.
# 5. **Visualize the results**: Create a bar chart to highlight the top products and their order counts.
#
# This will give you a clear view of the most popular products and their ranking.

# %%
# Merge Datasets
products_merged = order_products.merge(products, on='product_id')

# %%
# Group, Sort, and Display Data
merged_prod_grp = products_merged.groupby(by=['product_id', 'product_name']).size().sort_values(ascending=False)
top_20_products = merged_prod_grp.head(20)
print(top_20_products)
# Out:
# product_id  product_name
# 24852       banana                      66050
# 13176       bag of organic bananas      53297
# 21137       organic strawberries        37039
# 21903       organic baby spinach        33971
# 47209       organic hass avocado        29773
# 47766       organic avocado             24689
# 47626       large lemon                 21495
# 16797       strawberries                20018
# 26209       limes                       19690
# 27845       organic whole milk          19600
# 27966       organic raspberries         19197
# 22935       organic yellow onion        15898
# 24964       organic garlic              15292
# 45007       organic zucchini            14584
# 39275       organic blueberries         13879
# 49683       cucumber kirby              13675
# 28204       organic fuji apple          12544
# 5876        organic lemon               12232
# 8277        apple honeycrisp organic    11993
# 40706       organic grape tomatoes      11781
# dtype: int64

# %%
# Create a Bar Chart
top_20_products.plot(kind='bar', title='Top 20 Most Popular Products', 
                     x='product_name', xlabel='Product Name', 
                     y='col3', ylabel='Number Ordered', 
                     figsize=[10,10])
plt.show()

# %% [markdown]
# The top 20 items are all produce, except for the milk. Looks like people want delicious and nutritious!

# %% [markdown]
# # [C] Hard (must complete at least two to pass)

# %% [markdown]
# ### [C1] How many items do people typically buy in one order? What does the distribution look like?
# To analyze how many items people typically buy in one order:
#
# 1. **Group the data** by `order_id` and count the number of products (`product_id`) in each order using `.count()`. This gives the number of items in each order.
# 2. **Aggregate the counts**: Use `.value_counts()` to determine how frequently different order sizes occur, and then sort the results with `.sort_index()` to organize by the number of items.
# 3. **Visualize the distribution**: Use a bar plot to show the frequency of orders for each size, with the x-axis representing the number of items and the y-axis representing the number of orders.
#
# This will help you understand the typical size of a grocery order and identify any trends in purchasing behavior.

# %%
# Group and Count Data
order_id_grp = order_products.groupby('order_id')['product_id'].count()
order_size = order_id_grp.value_counts().sort_index()

# %%
# Visulaization - Bar Plot
order_size.plot(kind='bar', title='Frequency of Orders by Size', 
                x='col1', xlabel='Number of Items', 
                y='order_id', ylabel='Number of Orders', 
                figsize=[20,20])

plt.show()

# %% [markdown]
# Most of the order numbers are in the tail of the distribution. To get a better look at the non-tail part, let's choose a value in the tail as a cutoff and just plot order with fewer than that many items. An order size of 35 items is far enough into the tail for this.

# %%
# Filter the distribution
filtered_order_size = order_size[order_size.index < 35]

# Visulaization - Bar Plot
filtered_order_size.plot(kind='bar', title='Frequency of Orders by Size', 
                         x='col1', xlabel='Number of Items', 
                         y='order_id', ylabel='Number of Orders', 
                         figsize=[20,20])

plt.show()

# %% [markdown]
# The typical order contains 5 or 6 items, with most orders having between 1 and 20 items.

# %% [markdown]
# ### [C2] What are the top 20 items that are reordered most frequently (display their names and product IDs)?
#
# To find the top 20 most frequently reordered items:
#
# 1. **Filter the data**: Use `order_products['reordered'] == 1` to isolate only the products that have been reordered.
# 2. **Merge the datasets**: Combine the filtered `order_products` with the `products` dataset on `product_id` to get both the product names and IDs.
# 3. **Group the data**: Group by both `product_id` and `product_name` to calculate how many times each product was reordered, using `.size()`.
# 4. **Sort the results**: Use `.sort_values(ascending=False)` to rank the products by reorder frequency.
# 5. **Display the top 20**: Use `.head(20)` to focus on the most frequently reordered products.
# 6. **Visualize the data**: Create a bar chart to showcase the top reordered items and their frequencies.
#
# This process highlights the products that customers consistently return to and reorder.

# %%
# Filter Data
order_prod_filtered = order_products[order_products['reordered'] == 1]

# %%
# Merge Data
filtered_products_merged = order_prod_filtered.merge(products, on='product_id')

# %%
# Group and Data
top_reordered = filtered_products_merged.groupby(by=['product_id', 'product_name']).size() \
.sort_values(ascending=False).head(20).reset_index(name='reorder_count')

# Display the Top 20
print(top_reordered)
# Out:
#     product_id              product_name  reorder_count
# 0        24852                    banana          55763
# 1        13176    bag of organic bananas          44450
# 2        21137      organic strawberries          28639
# 3        21903      organic baby spinach          26233
# 4        47209      organic hass avocado          23629
# 5        47766           organic avocado          18743
# 6        27845        organic whole milk          16251
# 7        47626               large lemon          15044
# 8        27966       organic raspberries          14748
# 9        16797              strawberries          13945
# 10       26209                     limes          13327
# 11       22935      organic yellow onion          11145
# 12       24964            organic garlic          10411
# 13       45007          organic zucchini          10076
# 14       49683            cucumber kirby           9538
# 15       28204        organic fuji apple           8989
# 16        8277  apple honeycrisp organic           8836
# 17       39275       organic blueberries           8799
# 18        5876             organic lemon           8412
# 19       49235       organic half & half           8389

# %%
# Visualization - Bar Chart
top_reordered.plot(kind='bar', x='product_name', xlabel='Product Name', 
                   y='reorder_count', ylabel='Frequency of Reorder', 
                   figsize=[10,10], legend=False, title='Top 20 Most Reordered Products')

plt.show()

# %% [markdown]
# It looks like produce and dairy comprise the most reordered products as well. It makes sense that perishables would be the most reordered items.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 1</b>
#
# You've done a great job completing the tasks above.

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Reviewer's comment, v. 1</b>
#
# The following tasks are optional and not required for project acceptance. However, if you'd like them to be reviewed, please make sure to:
#
# - Display the **output** for each task so I can properly assess the results.
# - For the **final task**, make sure to **fix the error** in the code before resubmitting.
#
# This will ensure a smooth and complete review of all the work you've chosen to include.
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid blue">
# <b>Student’s Comment</b>
#
# I have corrected the error in the final task. Please review nad provide any feedback on the following optional tasks.
#
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 2</b>
#
# ✔️ Great job - I reviewed and left my comments below.
#
#
#
#
# </div>

# %% [markdown]
# ### [C3] For each product, what proportion of its orders are reorders?
#
# To calculate the proportion of orders for each product that are reorders:
#
# 1. **Merge the datasets**: Combine `order_products` with the `products` dataset to access product names and IDs in the same DataFrame.
# 2. **Group the data**: Group by `product_id` and `product_name` to isolate each product's order history.
# 3. **Calculate the mean of `reordered`**: Use `.mean()` on the `reordered` column to compute the proportion of orders for each product that were reorders. The value represents the reorder rate.
# 4. **Sort the results**: Use `.sort_values(ascending=False)` to rank products by their reorder rates.
# 5. **Convert to a DataFrame**: Use `.reset_index()` to organize the grouped data into a readable DataFrame.
# 6. **Optional Sorting**: Sort the results by `product_id` or another column for better clarity.
#
# This approach provides insights into how frequently each product is reordered, helping identify customer favorites or staples.

# %%
# Merge Datasets
products_merged = order_products.merge(products, on='product_id')

# %%
# Group, Calculate Mean, and Sort DF
prod_mrg_grp = products_merged.groupby(by=['product_id', 'product_name'])['reordered'].mean().sort_values(ascending=False)

# %%
# Convert to a DF
prod_mrg_grp = prod_mrg_grp.reset_index()

print(prod_mrg_grp)
# Out:
#        product_id                                       product_name  \
# 0           14721                            bone strength take care
# 1           20949                           vanilla sandwich cookies
# 2            6723                                   palmiers- petite
# 3            6732                  naturally sparkling mineral water
# 4           45088  california dill pollen & garlic goat cheese & ...
# ...           ...                                                ...
# 45568       10485                                  caramel apple pop
# 45569       37690  calypso fresh 2x concentrated scentsations 166...
# 45570       10484                                 avocado and greens
# 45571       10474                       nustevia white stevia powder
# 45572       42984  salsa for all seasons half guacamole half roas...
#
#        reordered
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
# ...          ...
# 45568        0.0
# 45569        0.0
# 45570        0.0
# 45571        0.0
# 45572        0.0
#
# [45573 rows x 3 columns]

# %% [markdown]
# ### [C4] For each customer, what proportion of their products ordered are reorders?
#
# To calculate the proportion of products reordered by each customer:
#
# 1. **Merge the datasets**: Combine `order_products` with `orders` to link order and customer information.
# 2. **Group the data**: Group by `user_id` to focus on each customer's ordering behavior.
# 3. **Calculate the mean of `reordered`**: Use `.mean()` on the `reordered` column to determine the proportion of products reordered by each customer.
# 4. **Sort the results**: Use `.sort_values(ascending=False)` to identify customers with the highest reorder rates.
# 5. **Convert to a DataFrame**: Use `.reset_index()` to format the grouped data into a structured DataFrame for further analysis.
#
# This analysis reveals the extent to which individual customers reorder products, providing insights into customer loyalty and preferences.

# %%
# Merge Dataset
cust_reorders_mrg = order_products.merge(orders, on='order_id')

# Grouped Dataset
reorders_mrg_grp = cust_reorders_mrg.groupby('user_id')

# Calculate Mean and Sort Dataset
mean_grp = reorders_mrg_grp['reordered'].mean().sort_values(ascending=False)

# %%
# Convert to a DF
mean_cust_reorders = mean_grp.reset_index()

print(mean_cust_reorders)
# Out:
#         user_id  reordered
# 0        137587        1.0
# 1        173474        1.0
# 2         13918        1.0
# 3         62300        1.0
# 4         62307        1.0
# ...         ...        ...
# 149621   190953        0.0
# 149622   119371        0.0
# 149623    63173        0.0
# 149624    63163        0.0
# 149625   165726        0.0
#
# [149626 rows x 2 columns]

# %% [markdown]
# ### [C5] What are the top 20 items that people put in their carts first?
#
# To identify the top 20 items that people most frequently add to their carts first:
#
# 1. **Merge the datasets**: Combine `order_products` with `products` to link product names and IDs.
# 2. **Filter the data**: Focus on rows where `add_to_cart_order` equals 1, indicating the first item added to the cart.
# 3. **Group the data**: Group by `product_id` and `product_name` to aggregate the count of how often each product was the first in a cart.
# 4. **Count occurrences**: Use `.count()` to calculate the total number of times each product was the first added.
# 5. **Sort the results**: Use `.sort_values(ascending=False)` to rank products by their first-in-cart frequency.
# 6. **Display the top 20**: Use `.head(20)` to extract the most popular first-in-cart items.
#
# This provides insights into which products customers prioritize in their shopping process.

# %%
# Merge datasets
first_pick_mrg = order_products.merge(products, on='product_id')

# Filter data for 'add_to_cart_order == 1'
first_pick_fltr = first_pick_mrg[first_pick_mrg['add_to_cart_order'] == 1]

# %%
# Group and Count Occurrences
first_pick_grp = first_pick_fltr.groupby(by=['product_id', 'product_name']).count()

# %%
# Sort Results
first_pick_item = first_pick_grp.sort_values(by='product_id', ascending=False)

# Display Top 20
print(first_pick_item.head(20))
# Out:
#                                                        order_id  \
# product_id product_name
# 49693      spring water body wash                             3
# 49691      original pancake & waffle mix                      3
# 49690      high performance energy drink                      2
# 49688      fresh foaming cleanser                             1
# 49687      smartblend healthy metabolism dry cat food         1
# 49686      artisan baguette                                   3
# 49685      en croute roast hazelnut cranberry                 1
# 49683      cucumber kirby                                  1078
# 49682      california limeade                                 2
# 49681      spaghetti with meatballs and sauce meal            2
# 49680      all natural creamy caesar dressing                12
# 49678      large chicken & cheese taquitos                    5
# 49677      thick & chunky sloppy joe sauce                    6
# 49671      milk chocolate drops                               1
# 49670      beef summer sausage                                1
# 49668      apple cinnamon scented candles                     3
# 49667      enchilada with spanish rice & beans meal          11
# 49664      unknown                                            2
# 49661      porto                                              1
# 49660      professionals sleek shampoo                        1
#
#                                                        add_to_cart_order  \
# product_id product_name
# 49693      spring water body wash                                      3
# 49691      original pancake & waffle mix                               3
# 49690      high performance energy drink                               2
# 49688      fresh foaming cleanser                                      1
# 49687      smartblend healthy metabolism dry cat food                  1
# 49686      artisan baguette                                            3
# 49685      en croute roast hazelnut cranberry                          1
# 49683      cucumber kirby                                           1078
# 49682      california limeade                                          2
# 49681      spaghetti with meatballs and sauce meal                     2
# 49680      all natural creamy caesar dressing                         12
# 49678      large chicken & cheese taquitos                             5
# 49677      thick & chunky sloppy joe sauce                             6
# 49671      milk chocolate drops                                        1
# 49670      beef summer sausage                                         1
# 49668      apple cinnamon scented candles                              3
# 49667      enchilada with spanish rice & beans meal                   11
# 49664      unknown                                                     2
# 49661      porto                                                       1
# 49660      professionals sleek shampoo                                 1
#
#                                                        reordered  aisle_id  \
# product_id product_name
# 49693      spring water body wash                              3         3
# 49691      original pancake & waffle mix                       3         3
# 49690      high performance energy drink                       2         2
# 49688      fresh foaming cleanser                              1         1
# 49687      smartblend healthy metabolism dry cat food          1         1
# 49686      artisan baguette                                    3         3
# 49685      en croute roast hazelnut cranberry                  1         1
# 49683      cucumber kirby                                   1078      1078
# 49682      california limeade                                  2         2
# 49681      spaghetti with meatballs and sauce meal             2         2
# 49680      all natural creamy caesar dressing                 12        12
# 49678      large chicken & cheese taquitos                     5         5
# 49677      thick & chunky sloppy joe sauce                     6         6
# 49671      milk chocolate drops                                1         1
# 49670      beef summer sausage                                 1         1
# 49668      apple cinnamon scented candles                      3         3
# 49667      enchilada with spanish rice & beans meal           11        11
# 49664      unknown                                             2         2
# 49661      porto                                               1         1
# 49660      professionals sleek shampoo                         1         1
#
#                                                        department_id
# product_id product_name
# 49693      spring water body wash                                  3
# 49691      original pancake & waffle mix                           3
# 49690      high performance energy drink                           2
# 49688      fresh foaming cleanser                                  1
# 49687      smartblend healthy metabolism dry cat food              1
# 49686      artisan baguette                                        3
# 49685      en croute roast hazelnut cranberry                      1
# 49683      cucumber kirby                                       1078
# 49682      california limeade                                      2
# 49681      spaghetti with meatballs and sauce meal                 2
# 49680      all natural creamy caesar dressing                     12
# 49678      large chicken & cheese taquitos                         5
# 49677      thick & chunky sloppy joe sauce                         6
# 49671      milk chocolate drops                                    1
# 49670      beef summer sausage                                     1
# 49668      apple cinnamon scented candles                          3
# 49667      enchilada with spanish rice & beans meal               11
# 49664      unknown                                                 2
# 49661      porto                                                   1
# 49660      professionals sleek shampoo                             1

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer’s comment, v. 2</b>
#
# You are sorting the products by their product ID, while you need to sort by the **number of orders in which they were first added to the cart**.
#
# Here is the way to select the top 20 by the number of orders in which they were first.
# </div>

# %%
#Added by reviewer
top_first_pick_items =  (#select only the items added first
                        first_pick_mrg[first_pick_mrg['add_to_cart_order'] == 1]
                        #group by product and count the number of orders
                         .groupby(by=['product_id', 'product_name'])['order_id'].count()
                        #sort by the number of orders
                         .sort_values(ascending=False)
                        #select top 20
                         .head(20)
                        )

top_first_pick_items
# Out:
# product_id  product_name
# 24852       banana                         15562
# 13176       bag of organic bananas         11026
# 27845       organic whole milk              4363
# 21137       organic strawberries            3946
# 47209       organic hass avocado            3390
# 21903       organic baby spinach            3336
# 47766       organic avocado                 3044
# 19660       spring water                    2336
# 16797       strawberries                    2308
# 27966       organic raspberries             2024
# 44632       sparkling water grapefruit      1914
# 49235       organic half & half             1797
# 47626       large lemon                     1737
# 196         soda                            1733
# 38689       organic reduced fat milk        1397
# 26209       limes                           1370
# 12341       hass avocados                   1340
# 5785        organic reduced fat 2% milk     1310
# 27086       half & half                     1309
# 43352       raspberries                     1246
# Name: order_id, dtype: int64

# %% [markdown]
# The products that are most often placed into the cart first are produce, dairy, and beverages such as soda or water. I couldn't really say why that is without experience using Instacart because this could have more to do with app design than properties of the products. I do notice that there is considerable overlap between this result and the previous result for most popular and most reordered item types. It could simply be that the app prioritizes popular items as the first suggested purchases, so it happens to be more convenient for customers to place these items in their cart first.

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Reviewer's comment, v. 1</b>
#
# The project will look more complete and professional if you add a conclusion summarising the main results of the analysis.
